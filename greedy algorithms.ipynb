# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# задача обработки заявок на время
# ![image.png](attachment:image.png)

# %% [markdown]
# можно сразу брать отрезок правыйконец которого минимален

# %% [markdown]
# алгоритм
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Задача чтоб на вечеринке не было непосредственного началника
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# непрерывный рюкзак
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
